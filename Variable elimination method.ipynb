# %%
# !pip install pgmpy
import networkx as nx
import matplotlib.pyplot as plt
from pgmpy.models import BayesianNetwork
from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination
# Define the structure of the Bayesian Network
model = BayesianNetwork([('Burglar', 'Alarm'), ('Earthquake', 'Alarm'), ('Alarm',
'JohnCalls'), ('Alarm', 'MaryCalls')])
model01=nx.Graph()
model01.add_nodes_from(['Burglar','Alarm','Earthquake','JohnCalls','MaryCalls'])
model01.add_edges_from([('Burglar', 'Alarm'), ('Earthquake', 'Alarm'), ('Alarm',
'JohnCalls'), ('Alarm', 'MaryCalls'),])
# CPD for the Burglar variable
cpd_burglar = TabularCPD(variable='Burglar', variable_card=2, values=[[0.999],
[0.001]])
# CPD for the Earthquake variable
cpd_earthquake = TabularCPD(variable='Earthquake', variable_card=2,
values=[[0.998], [0.002]])
# CPD for the Alarm variable given Burglar and Earthquake
cpd_alarm = TabularCPD(variable='Alarm', variable_card=2,values=[[0.999, 0.71,
0.06, 0.05], [0.001, 0.29, 0.94, 0.95]],evidence=['Burglar', 'Earthquake'],
evidence_card=[2, 2])
# CPD for JohnCalls given Alarm
cpd_johncalls = TabularCPD(variable='JohnCalls', variable_card=2,values=[[0.95,
0.1], [0.05, 0.9]],evidence=['Alarm'], evidence_card=[2])
# CPD for MaryCalls given Alarm
cpd_marycalls = TabularCPD(variable='MaryCalls', variable_card=2,values=[[0.7,
0.01], [0.3, 0.99]],evidence=['Alarm'], evidence_card=[2])
model.add_cpds(cpd_burglar, cpd_earthquake, cpd_alarm, cpd_johncalls,
cpd_marycalls)
model.check_model()
#pos = nx.spring_layout(model01, seed=42)
nx.draw(model01, with_labels=True,font_weight='bold',node_color='skyblue',
node_size=200,alpha=1,linewidths=10)
plt.title("Burglar Alarm Scenario Nodes")
plt.show()
plt.close()
model.get_cpds()
print('Burglar')
print(model.get_cpds('Burglar'))
print('Alarm')
print(model.get_cpds('Alarm'))

print('Earthquake')
print(model.get_cpds('Earthquake'))
print('JohnCalls')
print(model.get_cpds('JohnCalls'))
print('MarryCalls')
print(model.get_cpds('MaryCalls'))
# Create an inference object using Variable Elimination
inference = VariableElimination(model)
# Define the query variable, evidence variables, and their values
query_variable = 'Burglar'
evidence_variables = {'JohnCalls': 1, 'MaryCalls': 1}
# Compute the conditional probability distribution
result = inference.query(variables=[query_variable], evidence=evidence_variables)
# Print the conditional probability distribution
print('Conditional probability :\n',result)
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pgmpy in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (0.1.26)
# Requirement already satisfied: networkx in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pgmpy) (3.4.2)
# Requirement already satisfied: numpy in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pgmpy) (2.0.2)
# Requirement already satisfied: scipy in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pgmpy) (1.14.1)
# Requirement already satisfied: scikit-learn in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pgmpy) (1.5.2)
# Requirement already satisfied: pandas in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pgmpy) (2.2.3)
# Requirement already satisfied: pyparsing in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pgmpy) (3.2.0)
# Requirement already satisfied: torch in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pgmpy) (2.5.1)
# Requirement already satisfied: statsmodels in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pgmpy) (0.14.4)
# Requirement already satisfied: tqdm in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pgmpy) (4.67.1)
# Requirement already satisfied: joblib in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pgmpy) (1.4.2)
# Requirement already satisfied: opt-einsum in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pgmpy) (3.4.0)
# Requirement already satisfied: xgboost in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pgmpy) (2.1.3)
# Requirement already satisfied: google-generativeai in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pgmpy) (0.8.3)
# Requirement already satisfied: google-ai-generativelanguage==0.6.10 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai->pgmpy) (0.6.10)
# Requirement already satisfied: google-api-core in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai->pgmpy) (2.24.0)
# Requirement already satisfied: google-api-python-client in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai->pgmpy) (2.158.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai->pgmpy) (2.37.0)
# Requirement already satisfied: protobuf in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai->pgmpy) (5.28.3)
# Requirement already satisfied: pydantic in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai->pgmpy) (2.10.5)
# Requirement already satisfied: typing-extensions in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai->pgmpy) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-ai-generativelanguage==0.6.10->google-generativeai->pgmpy) (1.25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pandas->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pandas->pgmpy) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pandas->pgmpy) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->pgmpy) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from statsmodels->pgmpy) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from statsmodels->pgmpy) (24.1)
# Requirement already satisfied: filelock in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from torch->pgmpy) (3.16.1)
# Requirement already satisfied: jinja2 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from torch->pgmpy) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from torch->pgmpy) (2024.12.0)
# Requirement already satisfied: setuptools in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from torch->pgmpy) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from torch->pgmpy) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch->pgmpy) (1.3.0)
# Requirement already satisfied: colorama in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from tqdm->pgmpy) (0.4.6)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-api-core->google-generativeai->pgmpy) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-api-core->google-generativeai->pgmpy) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=2.15.0->google-generativeai->pgmpy) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=2.15.0->google-generativeai->pgmpy) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=2.15.0->google-generativeai->pgmpy) (4.9)
# Requirement already satisfied: six>=1.5 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->pgmpy) (1.16.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client->google-generativeai->pgmpy) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client->google-generativeai->pgmpy) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client->google-generativeai->pgmpy) (4.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch->pgmpy) (3.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pydantic->google-generativeai->pgmpy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pydantic->google-generativeai->pgmpy) (2.27.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai->pgmpy) (1.69.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai->pgmpy) (1.69.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai->pgmpy) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maxim\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (2024.8.30)
# Burglar
# +------------+-------+
# | Burglar(0) | 0.999 |
# +------------+-------+
# | Burglar(1) | 0.001 |
# +------------+-------+
# Alarm
# +------------+---------------+---------------+---------------+---------------+
# | Burglar    | Burglar(0)    | Burglar(0)    | Burglar(1)    | Burglar(1)    |
# +------------+---------------+---------------+---------------+---------------+
# | Earthquake | Earthquake(0) | Earthquake(1) | Earthquake(0) | Earthquake(1) |
# +------------+---------------+---------------+---------------+---------------+
# | Alarm(0)   | 0.999         | 0.71          | 0.06          | 0.05          |
# +------------+---------------+---------------+---------------+---------------+
# | Alarm(1)   | 0.001         | 0.29          | 0.94          | 0.95          |
# +------------+---------------+---------------+---------------+---------------+
# Earthquake
# +---------------+-------+
# | Earthquake(0) | 0.998 |
# +---------------+-------+
# | Earthquake(1) | 0.002 |
# +---------------+-------+
# JohnCalls
# +--------------+----------+----------+
# | Alarm        | Alarm(0) | Alarm(1) |
# +--------------+----------+----------+
# | JohnCalls(0) | 0.95     | 0.1      |
# +--------------+----------+----------+
# | JohnCalls(1) | 0.05     | 0.9      |
# +--------------+----------+----------+
# MarryCalls
# +--------------+----------+----------+
# | Alarm        | Alarm(0) | Alarm(1) |
# +--------------+----------+----------+
# | MaryCalls(0) | 0.7      | 0.01     |
# +--------------+----------+----------+
# | MaryCalls(1) | 0.3      | 0.99     |
# +--------------+----------+----------+
# Conditional probability :
#  +------------+----------------+
# | Burglar    |   phi(Burglar) |
# +============+================+
# | Burglar(0) |         0.9513 |
# +------------+----------------+
# | Burglar(1) |         0.0487 |
# +------------+----------------+
